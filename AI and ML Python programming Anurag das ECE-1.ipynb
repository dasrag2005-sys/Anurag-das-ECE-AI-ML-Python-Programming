# %%
name = input ( " Enter your name: " )
age = input ( " Enter your age: " )
dept = input ( " Enter your department: " )

print (f"My name is {name}, age is {age},dept is {department}")
# Out:
#  Enter your name:
#  Enter your age: 21
#  Enter your department: ece
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_151/883490652.py in <cell line: 0>()
#       3 dept = input ( " Enter your department: " )
#       4
# ----> 5 print (f"My name is {name}, age is {age},dept is {department}")
#
# NameError: name 'department' is not defined

# %%
# take two numbers as input and print it
city = input ("enter your city:")
print(city)

# %%
# take two numbers as input and print it
city = input ("enter your city")
print(city)
# Out:
# enter your citybarasat
# barasat

# %%
from os.path import join
# create variables for name,salary and job role
name = input("enter your name")
salary = float(input ("enter your salary"))
job_role = input ( " enter your job role ")
print (f" my name is {name} , age is {age} , my job role is {job_role}")
# Out:
# enter your nameanurag
# enter your salary23000
#  enter your job role chairman
#  my name is anurag , age is (18, 19, 45, 78, 89, 35) , my job role is chairman

# %%
#popular data types in python
# list in tuples
roles = ["ai engineer","freelance software developer ","designer","tester"]#tuple
age = ( 18 , 19 , 45 , 78 , 89 , 35 )#tuple

#set vs dictionary
name = {"alex","yuli"}

# %%
age = int(input("enter your age: "))

if age>18:
   print (" your safe to drive")
else:
    print ("opps look like you cant drive")
# Out:
# enter your age: 11
# opps look like you cant drive

# %%
#if else else if statement and indentation
# greatest among 3 we gotta find
a = int(input("enter a:"))
b = int(input("enter b:"))
c= int(input("enter c:"))

if a>b and a>c:
  print(" a is the greatest")
elif b>a and b>c:
  print(" b is the greatest")/home/student/Downloads/Untitled0(3).ipynb
else:
  print("c is the greatest")
# Out:
# enter a:12
# enter b:21
# enter c:11
#  b is the greatest

# %%
#module
import math

a = 25

print(math.sqrt(a))
# Out:
# 5.0

# %%
#how can u print current age and time
import datetime

a = datetime.datetime.now()

print(a)
# Out:
# 2026-03-16 07:21:23.534652
